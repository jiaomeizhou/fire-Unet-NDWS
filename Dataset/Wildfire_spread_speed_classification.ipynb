# %%
"""
This file is used to split the test dataset into subsets according to spread speed.
"""

# %%
# !pip install pandas numpy tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
import os

# Function to write a list of TFRecords to a specified file
def write_tfrecord(file_path, dataset):
    # Ensure the directory exists; create it if not
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Create a TFRecordWriter for the specified file path
    writer = tf.io.TFRecordWriter(file_path)

    # Write each example in the dataset to the TFRecord file
    for example in dataset:
        writer.write(example.SerializeToString())

    # Close the writer to finalize the file
    writer.close()

# Function to parse a TFRecord into a TensorFlow Example object
def parse_example(record):
    example = tf.train.Example()
    example.ParseFromString(record.numpy())
    return example

# Function to count the number of features in a TFRecord example
def count_features(example):
    return len(example.features.feature.keys())

# Function to classify fire change between two masks: PrevFireMask and FireMask
def classify_fire_change(prev_fire_mask, fire_mask):
    # Convert the PrevFireMask and FireMask to NumPy arrays and reshape them to 64x64
    prev_fire_mask_array = np.array(prev_fire_mask.float_list.value).reshape((64, 64))
    fire_mask_array = np.array(fire_mask.float_list.value).reshape((64, 64))

    # Filter out invalid data points (-1 values)
    valid_prev_fire_mask = prev_fire_mask_array[prev_fire_mask_array != -1]
    valid_fire_mask = fire_mask_array[fire_mask_array != -1]

    # Count the number of active fire pixels (values > 0) in both masks
    prev_fire_count = np.sum(valid_prev_fire_mask > 0.0)
    current_fire_count = np.sum(valid_fire_mask > 0.0)

    # Calculate the ratio of the current fire count to the previous fire count
    ratio = current_fire_count / prev_fire_count if prev_fire_count > 0 else 0

    # Print debug information to help trace computations
    print(f"Debug - prev_fire_count: {prev_fire_count}, current_fire_count: {current_fire_count}, ratio: {ratio:.2f}")

    # Classify the change in fire spread based on the ratio and counts
    if current_fire_count == 0 and prev_fire_count > 0:
        return "Fire extinguished"
    elif current_fire_count < prev_fire_count * 0.5:
        return "Quickly reduced"
    elif current_fire_count < prev_fire_count:
        return "Slowly reduced"
    elif current_fire_count > prev_fire_count * 1.5:
        return "Quickly spread"
    else:
        return "Slowly spread"

# Function to parse and classify a raw TFRecord
def _parse_and_classify_fn(raw_record):
    # Parse the raw record into a TensorFlow Example object
    example = parse_example(raw_record)

    # Extract the PrevFireMask and FireMask features from the example
    prev_fire_mask = example.features.feature['PrevFireMask']
    fire_mask = example.features.feature['FireMask']

    # Classify the fire change based on the masks
    fire_classification = classify_fire_change(prev_fire_mask, fire_mask)

    return example, prev_fire_mask, fire_mask, fire_classification

# Initialize lists to hold records for each fire classification
fire_extinguished_records = []
quickly_reduced_records = []
slowly_reduced_records = []
slowly_spread_records = []
quickly_spread_records = []

# Load the dataset using the specified file pattern
file_pattern = '/content/drive/My Drive/northamerica_2012-2023/test/*'
raw_dataset = tf.data.TFRecordDataset(tf.io.gfile.glob(file_pattern))

print("Starting to parse the dataset...")
for raw_record in raw_dataset:
    try:
        # Parse each record into an Example object
        example = parse_example(raw_record)

        # Check if the record has 13 features (specific to your dataset)
        if count_features(example) == 13:
            # Parse and classify the fire change based on the PrevFireMask and FireMask
            parsed_features, prev_fire_mask, fire_mask, classification = _parse_and_classify_fn(raw_record)

            # Extract and reshape the PrevFireMask and FireMask features
            prev_fire_mask_value = prev_fire_mask.float_list.value
            fire_mask_value = fire_mask.float_list.value
            prev_fire_mask_array = np.array(prev_fire_mask_value).reshape((64, 64))
            fire_mask_array = np.array(fire_mask_value).reshape((64, 64))

            # Count the number of active fire pixels (value of 1) in both masks
            count_1_prev = np.sum(prev_fire_mask_array == 1)
            count_1_fire = np.sum(fire_mask_array == 1)

            # Calculate the total number of valid pixels (non -1) and their ratios
            total_non_minus_1_prev = np.sum(prev_fire_mask_array != -1)
            total_non_minus_1_fire = np.sum(fire_mask_array != -1)
            ratio_prev = count_1_prev / total_non_minus_1_prev if total_non_minus_1_prev > 0 else 0
            ratio_fire = count_1_fire / total_non_minus_1_fire if total_non_minus_1_fire > 0 else 0

            # Print classification and ratio details for each record
            print(f"Record classification: {classification}")
            print(f"PrevFireMask - Count of 1 values: {count_1_prev}, Total non -1 values: {total_non_minus_1_prev}, Ratio: {ratio_prev:.2f}")
            print(f"FireMask - Count of 1 values: {count_1_fire}, Total non -1 values: {total_non_minus_1_fire}, Ratio: {ratio_fire:.2f}")

            # Append the example to the appropriate list based on classification
            if classification == "Fire extinguished":
                fire_extinguished_records.append(example)
            elif classification == "Quickly reduced":
                quickly_reduced_records.append(example)
            elif classification == "Slowly reduced":
                slowly_reduced_records.append(example)
            elif classification == "Slowly spread":
                slowly_spread_records.append(example)
            else:
                quickly_spread_records.append(example)
    except Exception as e:
        # Print error messages if parsing fails
        print(f"Error parsing record: {e}")
        print(f"Record: {raw_record}")

# Save each classification to a separate TFRecord file and print the number of records
write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_spreadspeed/fire_extinguished_data.tfrecords', fire_extinguished_records)
print(f"Fire extinguished records: {len(fire_extinguished_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_spreadspeed/quickly_reduced_data.tfrecords', quickly_reduced_records)
print(f"Quickly reduced records: {len(quickly_reduced_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_spreadspeed/slowly_reduced_data.tfrecords', slowly_reduced_records)
print(f"Slowly reduced records: {len(slowly_reduced_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_spreadspeed/slowly_spread_data.tfrecords', slowly_spread_records)
print(f"Slowly spread records: {len(slowly_spread_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_spreadspeed/quickly_spread_data.tfrecords', quickly_spread_records)
print(f"Quickly spread records: {len(quickly_spread_records)}")

print("Data has been classified and saved into respective TFRecord files.")
# Out:
# Streaming output truncated to the last 5000 lines.
# PrevFireMask - Count of 1 values: 73, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 2, current_fire_count: 17, ratio: 8.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 17, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 11, current_fire_count: 108, ratio: 9.82
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 11, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 1, current_fire_count: 13, ratio: 13.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 16, current_fire_count: 19, ratio: 1.19
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 16, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 6, current_fire_count: 43, ratio: 7.17
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 112, current_fire_count: 92, ratio: 0.82
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 112, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 92, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 134, current_fire_count: 74, ratio: 0.55
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 134, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 136, current_fire_count: 160, ratio: 1.18
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 136, Total non -1 values: 4086, Ratio: 0.03
# FireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# Debug - prev_fire_count: 3, current_fire_count: 108, ratio: 36.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 6, current_fire_count: 27, ratio: 4.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 3999, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 3870, Ratio: 0.01
# Debug - prev_fire_count: 136, current_fire_count: 160, ratio: 1.18
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 136, Total non -1 values: 4091, Ratio: 0.03
# FireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# Debug - prev_fire_count: 136, current_fire_count: 160, ratio: 1.18
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 136, Total non -1 values: 4091, Ratio: 0.03
# FireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# Debug - prev_fire_count: 14, current_fire_count: 24, ratio: 1.71
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 17, current_fire_count: 25, ratio: 1.47
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 17, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 25, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 80, current_fire_count: 69, ratio: 0.86
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 80, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 69, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 6, current_fire_count: 27, ratio: 4.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 3997, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 3857, Ratio: 0.01
# Debug - prev_fire_count: 3, current_fire_count: 6, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 136, current_fire_count: 160, ratio: 1.18
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 136, Total non -1 values: 4091, Ratio: 0.03
# FireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# Debug - prev_fire_count: 73, current_fire_count: 50, ratio: 0.68
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 73, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 2, current_fire_count: 6, ratio: 3.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 33, current_fire_count: 21, ratio: 0.64
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 33, Total non -1 values: 4073, Ratio: 0.01
# FireMask - Count of 1 values: 21, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 1, current_fire_count: 29, ratio: 29.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 29, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 136, current_fire_count: 160, ratio: 1.18
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 136, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 160, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 6, current_fire_count: 43, ratio: 7.17
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 11, current_fire_count: 108, ratio: 9.82
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 11, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 19, current_fire_count: 38, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 38, Total non -1 values: 4077, Ratio: 0.01
# Debug - prev_fire_count: 3, current_fire_count: 14, ratio: 4.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 40, current_fire_count: 30, ratio: 0.75
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 40, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 30, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 6, current_fire_count: 4, ratio: 0.67
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 4, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 8, current_fire_count: 53, ratio: 6.62
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 53, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 50, current_fire_count: 66, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 66, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 19, current_fire_count: 38, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 38, Total non -1 values: 4029, Ratio: 0.01
# Debug - prev_fire_count: 1, current_fire_count: 20, ratio: 20.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 6, current_fire_count: 27, ratio: 4.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 3997, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 3871, Ratio: 0.01
# Debug - prev_fire_count: 6, current_fire_count: 26, ratio: 4.33
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 26, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 134, current_fire_count: 74, ratio: 0.55
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 134, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 3, current_fire_count: 14, ratio: 4.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 60, current_fire_count: 103, ratio: 1.72
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 60, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 134, current_fire_count: 74, ratio: 0.55
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 134, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 50, current_fire_count: 66, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 66, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 134, current_fire_count: 74, ratio: 0.55
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 134, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4096, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 1, current_fire_count: 19, ratio: 19.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 19, current_fire_count: 38, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 38, Total non -1 values: 4067, Ratio: 0.01
# Debug - prev_fire_count: 64, current_fire_count: 103, ratio: 1.61
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 64, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 134, current_fire_count: 74, ratio: 0.55
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 134, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 25, current_fire_count: 6, ratio: 0.24
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 25, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 21, current_fire_count: 27, ratio: 1.29
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 21, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 14, current_fire_count: 9, ratio: 0.64
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4089, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 20, current_fire_count: 30, ratio: 1.50
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 30, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 3, current_fire_count: 20, ratio: 6.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 5, current_fire_count: 15, ratio: 3.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 3884, Ratio: 0.02
# Debug - prev_fire_count: 101, current_fire_count: 132, ratio: 1.31
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 101, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 132, Total non -1 values: 4088, Ratio: 0.03
# Debug - prev_fire_count: 111, current_fire_count: 148, ratio: 1.33
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 148, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 3, current_fire_count: 14, ratio: 4.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 92, current_fire_count: 38, ratio: 0.41
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 92, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 38, Total non -1 values: 4095, Ratio: 0.01
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 27, current_fire_count: 21, ratio: 0.78
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 21, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 17, current_fire_count: 27, ratio: 1.59
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 17, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 64, current_fire_count: 103, ratio: 1.61
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 64, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 1, current_fire_count: 1, ratio: 1.00
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4095, Ratio: 0.00
# FireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 20, current_fire_count: 30, ratio: 1.50
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 30, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 6, current_fire_count: 5, ratio: 0.83
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4095, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4087, Ratio: 0.03
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 15, current_fire_count: 19, ratio: 1.27
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 64, current_fire_count: 103, ratio: 1.61
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 64, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 21, current_fire_count: 14, ratio: 0.67
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 21, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4093, Ratio: 0.03
# Debug - prev_fire_count: 111, current_fire_count: 151, ratio: 1.36
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 151, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4094, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4045, Ratio: 0.00
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4094, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4067, Ratio: 0.00
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4096, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 20, current_fire_count: 30, ratio: 1.50
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 30, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 111, current_fire_count: 149, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 149, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 6, current_fire_count: 8, ratio: 1.33
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 1, current_fire_count: 19, ratio: 19.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 74, current_fire_count: 100, ratio: 1.35
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 100, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 22, current_fire_count: 32, ratio: 1.45
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 22, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 32, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 74, current_fire_count: 100, ratio: 1.35
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 100, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 15, current_fire_count: 19, ratio: 1.27
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 50, current_fire_count: 66, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 66, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 10, current_fire_count: 20, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 10, Total non -1 values: 4060, Ratio: 0.00
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 50, current_fire_count: 66, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 66, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 74, current_fire_count: 100, ratio: 1.35
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 100, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 14, current_fire_count: 9, ratio: 0.64
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 4042, Ratio: 0.02
# Debug - prev_fire_count: 5, current_fire_count: 12, ratio: 2.40
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 12, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4094, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4045, Ratio: 0.00
# Debug - prev_fire_count: 57, current_fire_count: 103, ratio: 1.81
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 57, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 21, current_fire_count: 27, ratio: 1.29
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 21, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 6, current_fire_count: 26, ratio: 4.33
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 26, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 20, current_fire_count: 30, ratio: 1.50
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 30, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 8, current_fire_count: 8, ratio: 1.00
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 111, current_fire_count: 148, ratio: 1.33
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 148, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 6, current_fire_count: 5, ratio: 0.83
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 107, current_fire_count: 132, ratio: 1.23
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 107, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4093, Ratio: 0.03
# Debug - prev_fire_count: 101, current_fire_count: 132, ratio: 1.31
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 101, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 1, current_fire_count: 7, ratio: 7.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4060, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 8, current_fire_count: 53, ratio: 6.62
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 53, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 111, current_fire_count: 148, ratio: 1.33
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 148, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 3, current_fire_count: 20, ratio: 6.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 3943, Ratio: 0.02
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 5, current_fire_count: 12, ratio: 2.40
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 12, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 50, current_fire_count: 66, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 50, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 66, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 38, current_fire_count: 20, ratio: 0.53
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 38, Total non -1 values: 4083, Ratio: 0.01
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 24, current_fire_count: 26, ratio: 1.08
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 26, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 1, current_fire_count: 19, ratio: 19.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 3906, Ratio: 0.02
# Debug - prev_fire_count: 1, current_fire_count: 19, ratio: 19.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 4026, Ratio: 0.02
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 108, current_fire_count: 132, ratio: 1.22
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 132, Total non -1 values: 4095, Ratio: 0.03
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 3934, Ratio: 0.02
# Debug - prev_fire_count: 160, current_fire_count: 214, ratio: 1.34
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 160, Total non -1 values: 4095, Ratio: 0.04
# FireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 108, current_fire_count: 141, ratio: 1.31
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 141, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 25, current_fire_count: 25, ratio: 1.00
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 25, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 25, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 38, current_fire_count: 87, ratio: 2.29
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 38, Total non -1 values: 4095, Ratio: 0.01
# FireMask - Count of 1 values: 87, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 3, current_fire_count: 3, ratio: 1.00
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 3, current_fire_count: 4, ratio: 1.33
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4092, Ratio: 0.00
# FireMask - Count of 1 values: 4, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 132, current_fire_count: 190, ratio: 1.44
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 190, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 15, current_fire_count: 19, ratio: 1.27
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 214, current_fire_count: 84, ratio: 0.39
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# FireMask - Count of 1 values: 84, Total non -1 values: 4086, Ratio: 0.02
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 14, current_fire_count: 80, ratio: 5.71
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 80, Total non -1 values: 4089, Ratio: 0.02
# Debug - prev_fire_count: 111, current_fire_count: 152, ratio: 1.37
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 111, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 152, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 26, current_fire_count: 37, ratio: 1.42
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 26, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 37, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 10, current_fire_count: 20, ratio: 2.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 10, Total non -1 values: 4055, Ratio: 0.00
# FireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 26, current_fire_count: 37, ratio: 1.42
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 26, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 37, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 106, current_fire_count: 140, ratio: 1.32
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 106, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 140, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 22, current_fire_count: 8, ratio: 0.36
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 22, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 5, current_fire_count: 15, ratio: 3.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 214, current_fire_count: 84, ratio: 0.39
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# FireMask - Count of 1 values: 84, Total non -1 values: 4086, Ratio: 0.02
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 3974, Ratio: 0.02
# Debug - prev_fire_count: 103, current_fire_count: 68, ratio: 0.66
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 68, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 20, current_fire_count: 150, ratio: 7.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 20, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 150, Total non -1 values: 4096, Ratio: 0.04
# Debug - prev_fire_count: 7, current_fire_count: 5, ratio: 0.71
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 5, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 214, current_fire_count: 84, ratio: 0.39
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 214, Total non -1 values: 4096, Ratio: 0.05
# FireMask - Count of 1 values: 84, Total non -1 values: 4086, Ratio: 0.02
# Debug - prev_fire_count: 74, current_fire_count: 100, ratio: 1.35
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 100, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 43, current_fire_count: 94, ratio: 2.19
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 43, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 94, Total non -1 values: 4037, Ratio: 0.02
# Debug - prev_fire_count: 132, current_fire_count: 190, ratio: 1.44
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 132, Total non -1 values: 4095, Ratio: 0.03
# FireMask - Count of 1 values: 190, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 74, current_fire_count: 100, ratio: 1.35
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 74, Total non -1 values: 4096, Ratio: 0.02
# FireMask - Count of 1 values: 100, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 1, current_fire_count: 27, ratio: 27.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 3, current_fire_count: 36, ratio: 12.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 36, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 126, current_fire_count: 185, ratio: 1.47
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 126, Total non -1 values: 4086, Ratio: 0.03
# FireMask - Count of 1 values: 185, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 108, current_fire_count: 109, ratio: 1.01
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 109, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 2, current_fire_count: 10, ratio: 5.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 59, current_fire_count: 27, ratio: 0.46
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 59, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 8, current_fire_count: 10, ratio: 1.25
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 8, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 132, current_fire_count: 190, ratio: 1.44
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 132, Total non -1 values: 4095, Ratio: 0.03
# FireMask - Count of 1 values: 190, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 9, current_fire_count: 27, ratio: 3.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4092, Ratio: 0.00
# FireMask - Count of 1 values: 27, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 19, current_fire_count: 41, ratio: 2.16
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 41, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 108, current_fire_count: 109, ratio: 1.01
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 109, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 108, current_fire_count: 109, ratio: 1.01
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 109, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 103, current_fire_count: 68, ratio: 0.66
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 103, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 68, Total non -1 values: 4096, Ratio: 0.02
# Debug - prev_fire_count: 108, current_fire_count: 109, ratio: 1.01
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 109, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 132, current_fire_count: 190, ratio: 1.44
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 132, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 190, Total non -1 values: 4096, Ratio: 0.05
# Debug - prev_fire_count: 2, current_fire_count: 7, ratio: 3.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 19, current_fire_count: 23, ratio: 1.21
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 19, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 23, Total non -1 values: 4094, Ratio: 0.01
# Debug - prev_fire_count: 108, current_fire_count: 109, ratio: 1.01
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 108, Total non -1 values: 4096, Ratio: 0.03
# FireMask - Count of 1 values: 109, Total non -1 values: 4096, Ratio: 0.03
# Debug - prev_fire_count: 132, current_fire_count: 190, ratio: 1.44
# Record classification: Slowly spread
# ...
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 58, current_fire_count: 14, ratio: 0.24
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 58, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 60, current_fire_count: 14, ratio: 0.23
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 60, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 2, current_fire_count: 11, ratio: 5.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 58, current_fire_count: 14, ratio: 0.24
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 58, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 24, ratio: 2.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 2, current_fire_count: 11, ratio: 5.50
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 4, current_fire_count: 3, ratio: 0.75
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 4089, Ratio: 0.00
# FireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 24, ratio: 2.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 2, current_fire_count: 10, ratio: 5.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4085, Ratio: 0.00
# FireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 2, current_fire_count: 10, ratio: 5.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4069, Ratio: 0.00
# FireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 7, ratio: 7.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 2, current_fire_count: 10, ratio: 5.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 2, Total non -1 values: 4087, Ratio: 0.00
# FireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 56, current_fire_count: 14, ratio: 0.25
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 56, Total non -1 values: 4096, Ratio: 0.01
# FireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 7, ratio: 7.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 24, ratio: 2.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 3, current_fire_count: 1, ratio: 0.33
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 3, Total non -1 values: 2287, Ratio: 0.00
# FireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 7, ratio: 7.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 4, current_fire_count: 3, ratio: 0.75
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 4090, Ratio: 0.00
# FireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 24, ratio: 2.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 9, current_fire_count: 24, ratio: 2.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 24, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 4, current_fire_count: 3, ratio: 0.75
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 4088, Ratio: 0.00
# FireMask - Count of 1 values: 3, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 9, current_fire_count: 15, ratio: 1.67
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 9, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 9, ratio: 9.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 9, Total non -1 values: 4037, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4088, Ratio: 0.01
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4088, Ratio: 0.01
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4083, Ratio: 0.01
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4083, Ratio: 0.01
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 4, current_fire_count: 5, ratio: 1.25
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 3890, Ratio: 0.00
# FireMask - Count of 1 values: 5, Total non -1 values: 4080, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4083, Ratio: 0.01
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 10, current_fire_count: 3, ratio: 0.30
# Record classification: Quickly reduced
# PrevFireMask - Count of 1 values: 10, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 3, Total non -1 values: 3989, Ratio: 0.00
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 7, current_fire_count: 13, ratio: 1.86
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4084, Ratio: 0.01
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 9, ratio: 9.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 9, Total non -1 values: 4037, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 14, current_fire_count: 11, ratio: 0.79
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 14, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 11, Total non -1 values: 4094, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4085, Ratio: 0.01
# Debug - prev_fire_count: 4, current_fire_count: 5, ratio: 1.25
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 3901, Ratio: 0.00
# FireMask - Count of 1 values: 5, Total non -1 values: 4070, Ratio: 0.00
# Debug - prev_fire_count: 1, current_fire_count: 9, ratio: 9.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 9, Total non -1 values: 4031, Ratio: 0.00
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4089, Ratio: 0.01
# Debug - prev_fire_count: 15, current_fire_count: 37, ratio: 2.47
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 15, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 37, Total non -1 values: 4096, Ratio: 0.01
# Debug - prev_fire_count: 1, current_fire_count: 4, ratio: 4.00
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 1, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 4, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 7, current_fire_count: 7, ratio: 1.00
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 6, current_fire_count: 7, ratio: 1.17
# Record classification: Slowly spread
# PrevFireMask - Count of 1 values: 6, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 4, current_fire_count: 7, ratio: 1.75
# Record classification: Quickly spread
# PrevFireMask - Count of 1 values: 4, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Debug - prev_fire_count: 13, current_fire_count: 7, ratio: 0.54
# Record classification: Slowly reduced
# PrevFireMask - Count of 1 values: 13, Total non -1 values: 4096, Ratio: 0.00
# FireMask - Count of 1 values: 7, Total non -1 values: 4096, Ratio: 0.00
# Fire extinguished records: 0
# Quickly reduced records: 909
# Slowly reduced records: 1583
# Slowly spread records: 1493
# Quickly spread records: 4234
# Data has been classified and saved into respective TFRecord files.
