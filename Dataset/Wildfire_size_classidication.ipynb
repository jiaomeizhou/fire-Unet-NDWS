# %%
"""
This file is used to split the test dataset into sub test sets according to large, medium, and small fire.
"""

# %%
# !pip install pandas numpy tensorflow
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np

# Function to write a list of TFRecords to a file
def write_tfrecord(file_path, dataset):
    writer = tf.io.TFRecordWriter(file_path)
    for example in dataset:
        writer.write(example.SerializeToString())
    writer.close()

# Function to parse a TFRecord into a TensorFlow Example object
def parse_example(record):
    example = tf.train.Example()
    example.ParseFromString(record.numpy())
    return example

# Function to count the number of features in a TFRecord example
def count_features(example):
    return len(example.features.feature.keys())

# Function to classify the fire size based on the PrevFireMask feature
def classify_fire(prev_fire_mask):
    # Convert the PrevFireMask to a NumPy array and reshape to 64x64
    prev_fire_mask_array = np.array(prev_fire_mask.float_list.value).reshape((64, 64))

    # Count the number of -1, 0, and 1 values in the array
    count_minus_1 = np.sum(prev_fire_mask_array == -1)
    count_0 = np.sum(prev_fire_mask_array == 0)
    count_1 = np.sum(prev_fire_mask_array == 1)

    # Calculate the total number of non -1 values and the ratio of 1 values
    total_non_minus_1 = np.sum(prev_fire_mask_array != -1)
    ratio_1 = count_1 / total_non_minus_1 if total_non_minus_1 > 0 else 0

    # Print debug information to help trace computations
    print(f"Debug - count_minus_1: {count_minus_1}, count_0: {count_0}, count_1: {count_1}, total_non_minus_1: {total_non_minus_1}, ratio_1: {ratio_1:.2f}")

    # Classify the fire based on the ratio of 1 values
    if ratio_1 > 0.1:
        return "Large fire"
    elif ratio_1 > 0.05:
        return "Medium fire"
    else:
        return "Small fire"

# Function to parse the raw record and classify the fire
def _parse_and_classify_fn(raw_record):
    # Parse the TFRecord into an Example
    example = parse_example(raw_record)

    # Extract the PrevFireMask and FireMask features
    prev_fire_mask = example.features.feature['PrevFireMask']
    fire_mask = example.features.feature['FireMask']

    # Classify the fire based on the PrevFireMask
    fire_classification = classify_fire(prev_fire_mask)

    return example, prev_fire_mask, fire_mask, fire_classification

# Initialize lists to hold records for each fire classification
no_fire_records = []
small_fire_records = []
medium_fire_records = []
large_fire_records = []
very_large_fire_records = []

# Load the dataset from the specified file pattern
file_pattern = '/content/drive/My Drive/northamerica_2012-2023/test/*'
raw_dataset = tf.data.TFRecordDataset(tf.io.gfile.glob(file_pattern))

print("Starting to parse the dataset...")
for raw_record in raw_dataset:
    try:
        # Parse each record into an Example object
        example = parse_example(raw_record)

        # Check if the record has 13 features (specific to your dataset)
        if count_features(example) == 13:
            # Parse and classify the fire based on the PrevFireMask
            parsed_features, prev_fire_mask, fire_mask, classification = _parse_and_classify_fn(raw_record)

            # Extract and reshape the PrevFireMask feature
            prev_fire_mask_value = prev_fire_mask.float_list.value
            prev_fire_mask_array = np.array(prev_fire_mask_value).reshape((64, 64))

            # Count the number of 1 values and calculate the ratio
            count_1 = np.sum(prev_fire_mask_array == 1)
            total_non_minus_1 = np.sum(prev_fire_mask_array != -1)
            ratio_1 = count_1 / total_non_minus_1 if total_non_minus_1 > 0 else 0

            # Print classification and ratio details for each record
            print(f"Record classification: {classification}")
            print(f"Count of 1 values: {count_1}")
            print(f"Total non -1 values: {total_non_minus_1}")
            print(f"Ratio of 1 values to non -1 values: {ratio_1:.2f}")

            # Append the example to the appropriate list based on classification
            if classification == "No fire":
                no_fire_records.append(example)
            elif classification == "Small fire":
                small_fire_records.append(example)
            elif classification == "Medium fire":
                medium_fire_records.append(example)
            elif classification == "Large fire":
                large_fire_records.append(example)
            else:
                very_large_fire_records.append(example)
    except Exception as e:
        # Print error messages if parsing fails
        print(f"Error parsing record: {e}")
        print(f"Record: {raw_record}")

# Save each classification to a separate TFRecord file and print the number of records
write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_firesize/no_fire_data.tfrecords', no_fire_records)
print(f"No fire records: {len(no_fire_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_firesize/small_fire_data.tfrecords', small_fire_records)
print(f"Small fire records: {len(small_fire_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_firesize/medium_fire_data.tfrecords', medium_fire_records)
print(f"Medium fire records: {len(medium_fire_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_firesize/large_fire_data.tfrecords', large_fire_records)
print(f"Large fire records: {len(large_fire_records)}")

write_tfrecord('/content/drive/MyDrive/new_wildfire_subsets_by_firesize/very_large_fire_data.tfrecords', very_large_fire_records)
print(f"Very large fire records: {len(very_large_fire_records)}")

print("Data has been classified and saved into respective TFRecord files.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Record classification: Small fire
# Count of 1 values: 19
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 1, count_0: 4057, count_1: 38, total_non_minus_1: 4095, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 38
# Total non -1 values: 4095
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4037, count_1: 59, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 59
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 4, count_0: 4087, count_1: 5, total_non_minus_1: 4092, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 5
# Total non -1 values: 4092
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4037, count_1: 59, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 59
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3988, count_1: 108, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 108
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4091, count_1: 5, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 5
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 14, count_0: 4080, count_1: 2, total_non_minus_1: 4082, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4082
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 1, count_0: 4093, count_1: 2, total_non_minus_1: 4095, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4095
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4085, count_1: 11, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 11
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4088, count_1: 8, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 8
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 13, count_0: 4081, count_1: 2, total_non_minus_1: 4083, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4083
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4085, count_1: 11, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 11
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4069, count_1: 27, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3987, count_1: 109, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 109
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 14, count_0: 4055, count_1: 27, total_non_minus_1: 4082, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 27
# Total non -1 values: 4082
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 63, count_0: 3912, count_1: 121, total_non_minus_1: 4033, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4033
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4091, count_1: 5, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 5
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4088, count_1: 8, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 8
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3975, count_1: 121, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 61, count_0: 3914, count_1: 121, total_non_minus_1: 4035, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4035
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 2, count_0: 3973, count_1: 121, total_non_minus_1: 4094, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4094
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 18, count_0: 4067, count_1: 11, total_non_minus_1: 4078, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 11
# Total non -1 values: 4078
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3975, count_1: 121, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 9, count_0: 4080, count_1: 7, total_non_minus_1: 4087, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4087
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 56, count_0: 3919, count_1: 121, total_non_minus_1: 4040, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4040
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3975, count_1: 121, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3975, count_1: 121, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3975, count_1: 121, total_non_minus_1: 4096, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4091, count_1: 5, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 5
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 75, count_0: 3900, count_1: 121, total_non_minus_1: 4021, ratio_1: 0.03
# Record classification: Small fire
# Count of 1 values: 121
# Total non -1 values: 4021
# Ratio of 1 values to non -1 values: 0.03
# Debug - count_minus_1: 1, count_0: 4087, count_1: 8, total_non_minus_1: 4095, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 8
# Total non -1 values: 4095
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4091, count_1: 5, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 5
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4090, count_1: 6, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 6
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 3947, count_1: 149, total_non_minus_1: 4096, ratio_1: 0.04
# Record classification: Small fire
# Count of 1 values: 149
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.04
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 100, count_0: 3986, count_1: 10, total_non_minus_1: 3996, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 10
# Total non -1 values: 3996
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4090, count_1: 6, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 6
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4065, count_1: 31, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 31
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4090, count_1: 6, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 6
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 4, count_0: 4090, count_1: 2, total_non_minus_1: 4092, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4092
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4093, count_1: 3, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4060, count_1: 36, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 36
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4024, count_1: 72, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 72
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4046, count_1: 50, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 50
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 8, count_0: 4086, count_1: 2, total_non_minus_1: 4088, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4088
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 18, count_0: 4077, count_1: 1, total_non_minus_1: 4078, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4078
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 18, count_0: 4077, count_1: 1, total_non_minus_1: 4078, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4078
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 8, count_0: 4086, count_1: 2, total_non_minus_1: 4088, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# ...
# Count of 1 values: 75
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4021, count_1: 75, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 75
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4021, count_1: 75, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 75
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4021, count_1: 75, total_non_minus_1: 4096, ratio_1: 0.02
# Record classification: Small fire
# Count of 1 values: 75
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.02
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 383, count_0: 3712, count_1: 1, total_non_minus_1: 3713, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 3713
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 1, count_0: 4094, count_1: 1, total_non_minus_1: 4095, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4095
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4088, count_1: 8, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 8
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4038, count_1: 58, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 58
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4036, count_1: 60, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 60
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4038, count_1: 58, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 58
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4094, count_1: 2, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 7, count_0: 4085, count_1: 4, total_non_minus_1: 4089, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4089
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 11, count_0: 4083, count_1: 2, total_non_minus_1: 4085, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4085
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 27, count_0: 4067, count_1: 2, total_non_minus_1: 4069, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4069
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 9, count_0: 4085, count_1: 2, total_non_minus_1: 4087, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 2
# Total non -1 values: 4087
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4040, count_1: 56, total_non_minus_1: 4096, ratio_1: 0.01
# Record classification: Small fire
# Count of 1 values: 56
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.01
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 1809, count_0: 2284, count_1: 3, total_non_minus_1: 2287, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 3
# Total non -1 values: 2287
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 6, count_0: 4086, count_1: 4, total_non_minus_1: 4090, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4090
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 8, count_0: 4084, count_1: 4, total_non_minus_1: 4088, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4088
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4087, count_1: 9, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 9
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 206, count_0: 3886, count_1: 4, total_non_minus_1: 3890, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 3890
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4086, count_1: 10, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 10
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4082, count_1: 14, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 14
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 195, count_0: 3897, count_1: 4, total_non_minus_1: 3901, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 3901
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4081, count_1: 15, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 15
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4095, count_1: 1, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 1
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4089, count_1: 7, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 7
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4090, count_1: 6, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 6
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4092, count_1: 4, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 4
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# Debug - count_minus_1: 0, count_0: 4083, count_1: 13, total_non_minus_1: 4096, ratio_1: 0.00
# Record classification: Small fire
# Count of 1 values: 13
# Total non -1 values: 4096
# Ratio of 1 values to non -1 values: 0.00
# No fire records: 0
# Small fire records: 8047
# Medium fire records: 151
# Large fire records: 21
# Very large fire records: 0
# Data has been classified and saved into respective TFRecord files.
